# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# **Creating A DataFrame**

# %%
data = {
    'Name' : ['John', 'Anna', 'Peter', 'Linda'],
    'Age' : [28,34,29,42],
    'City' : ['New yourk', 'Paris', 'Berlin', 'London'], 
    'Salary' : [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age       City  Salary
# 0   John   28  New yourk   65000
# 1   Anna   34      Paris   70000
# 2  Peter   29     Berlin   62000
# 3  Linda   42     London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000], 
    ['Anna', 34, 'Paris', 70000], 
    ['Peter', 29, 'Berlin', 62000], 
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
coloumns = ["Name", "age", "City", "Salary"]
df2 = pd.DataFrame(data_list, columns = coloumns)
df2
# Out:
#     Name  age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# **Selection And Indexing Of Coloumns**

# %%
df2["Name"]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2["City"]
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df2[["Name", "City", "age"]]
# Out:
#     Name      City  age
# 0   John  New York   28
# 1   Anna     Paris   34
# 2  Peter    Berlin   29
# 3  Linda    London   42

# %% [markdown]
# **Creating A new Coloumn**

# %%
df2["Designation"] = ["Doctor", "Engg", "Doctor", "Engg"]
df2
# Out:
#     Name  age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Engg
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Engg

# %% [markdown]
# **Removing Coloumns**

# %%
#Delete a Copy of Coloumn. 
df2.drop("Designation", axis=1)
df2
# Out:
#     Name  age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Engg
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Engg

# %%
#Delete Coloumn peranently 
df2.drop("Designation", axis=1, inplace=True)
df2
# Out:
#     Name  age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#Delete Multiple ccoloumns 
df2.drop(["Salary", "City" ], axis=1)
# Out:
#     Name  age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#Delete a copy of Row. 
df2.drop(3,axis=0)
df2
# Out:
#     Name  age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#Delete row permanently
df2.drop(3, axis=0, inplace=True)
df2
# Out:
#     Name  age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000

# %%
#Delete multiple rows 
df2.drop(, axis=0)
df2
# Out:
#     Name  age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000

# %% [markdown]
# **Selecting Rows**

# %%
df2
# Out:
#     Name  age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000

# %%
df2.loc[0]
# Out:
# Name          John
# age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %% [markdown]
# **Selecting Subset Of Rows And Coloumns**

# %%
df2
# Out:
#     Name  age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000

# %%
df2.loc[[0,1]][["City", "Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[1,2]][["Name", "age"]]
# Out:
#     Name  age
# 1   Anna   34
# 2  Peter   29

# %% [markdown]
# **Conditional Selection**

# %%
df2
# Out:
#     Name  age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000

# %%
#I want to only see those whose age is about 30
df2[df2["age"] > 30]
# Out:
#    Name  age   City  Salary
# 1  Anna   34  Paris   70000

# %%
df2[(df2["age"] > 30) & (df2["City"] == 'Paris')]
# Out:
#    Name  age   City  Salary
# 1  Anna   34  Paris   70000
